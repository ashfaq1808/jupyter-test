# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('auto.csv')

# %%
print(df.head())
print(df.describe())
# Out:
#    horsepower  price  highway-mpg
# 0         130  15000           30
# 1         165  17500           22
# 2         150  12000           25
# 3         140  16000           27
# 4         200  22000           20
#        horsepower         price  highway-mpg
# count    5.000000      5.000000     5.000000
# mean   157.000000  16500.000000    24.800000
# std     27.294688   3674.234614     3.962323
# min    130.000000  12000.000000    20.000000
# 25%    140.000000  15000.000000    22.000000
# 50%    150.000000  16000.000000    25.000000
# 75%    165.000000  17500.000000    27.000000
# max    200.000000  22000.000000    30.000000

# %%
df.dropna(inplace=True)  # Removing rows with missing values

# %%
print(df[['horsepower', 'price', 'highway-mpg']].corr())
# Out:
#              horsepower     price  highway-mpg
# horsepower     1.000000  0.810174    -0.943131
# price          0.810174  1.000000    -0.669712
# highway-mpg   -0.943131 -0.669712     1.000000

# %%
plt.scatter(df['horsepower'], df['price'])
plt.title('Horsepower vs. Price')
plt.xlabel('Horsepower')
plt.ylabel('Price')
plt.show()

# %%
df['highway-mpg'].plot(kind='hist', bins=10, color='blue')
plt.title('Distribution of Highway MPG')
plt.xlabel('Highway MPG')
plt.ylabel('Frequency')
plt.show()
